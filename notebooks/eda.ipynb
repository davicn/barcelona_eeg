# %%
import pandas as pd
import seaborn as sns

# %%
df  = pd.read_parquet('dataset.parquet')

# %%
df.dtypes
# Out:
# var_x               float64
# var_y               float64
# skew_x              float64
# skew_y              float64
# kur_x               float64
# kur_y               float64
# entropy_x           float64
# entropy_y           float64
# var_x+entropy_x     float64
# var_y+entropy_y     float64
# kur_x+entropy_x     float64
# kur_y+entropy_y     float64
# skew_x+entropy_x    float64
# skew_y+entropy_y    float64
# var_x+skew_x        float64
# var_y+skew_y        float64
# kur_x+skew_x        float64
# kur_y+skew_y        float64
# label                object
# dtype: object

# %%
sns.pairplot(df.loc[:,['var_x+entropy_x','var_y+entropy_y','label']],hue='label')

# %%
sns.pairplot(df.loc[:,['kur_x+entropy_x','kur_y+entropy_y','label']],hue='label')
